# %%
import numpy as np
from numpy.linalg import inv
from matplotlib import pyplot as plt
import pandas as pd

address = 'D:/HomeWork/Machine Learning/ML-HW01/ML-HW01/dataset2/saved_file.xlsx'
data = pd.read_excel(address)
data.pop('Ratings')

data.head(5)
# Out:
#    Movie  Year  Genre      Gross       Budget  Screens  Sequel  Sentiment  \
# 0      0  2014      8       9130    4000000.0     45.0       1          0
# 1      1  2014      1  192000000   50000000.0   3306.0       2          2
# 2      2  2014      1   30700000   28000000.0   2872.0       1          0
# 3      3  2014      1  106000000  110000000.0   3470.0       2          0
# 4      4  2014      8   17300000    3500000.0   2310.0       2          0
#
#      Views  Likes  Dislikes  Comments  Aggregate Followers
# 0  3280543   4632       425       636            1120000.0
# 1   583289   3465        61       186           12350000.0
# 2   304861    328        34        47             483000.0
# 3   452917   2429       132       590             568000.0
# 4  3145573  12163       610      1082            1923800.0

# %%
corrMatrix = data.corr().abs()
f = plt.figure(figsize=(19, 15))
plt.matshow(corrMatrix, fignum=f.number)
plt.xticks(range(data.select_dtypes(['number']).shape[1]), data.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(data.select_dtypes(['number']).shape[1]), data.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
corrMatrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_c8252_row0_col0,#T_c8252_row1_col1,#T_c8252_row2_col2,#T_c8252_row3_col3,#T_c8252_row4_col4,#T_c8252_row5_col5,#T_c8252_row6_col6,#T_c8252_row7_col7,#T_c8252_row8_col8,#T_c8252_row9_col9,#T_c8252_row10_col10,#T_c8252_row11_col11,#T_c8252_row12_col12{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c8252_row0_col1,#T_c8252_row0_col11,#T_c8252_row2_col7,#T_c8252_row2_col8,#T_c8252_row2_col10,#T_c8252_row2_col12,#T_c8252_row4_col9,#T_c8252_row7_col2,#T_c8252_row7_col3,#T_c8252_row7_col5,#T_c8252_row9_col4,#T_c8252_row9_col6,#T_c8252_row11_col0,#T_c8252_row12_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_c8252_row0_col2,#T_c8252_row1_col4,#T_c8252_row4_col1,#T_c8252_row4_col11,#T_c8252_row10_col0,#T_c8252_row10_col4{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_c8252_row0_col3,#T_c8252_row11_col2{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_c8252_row0_col4,#T_c8252_row0_col10,#T_c8252_row6_col0{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_c8252_row0_col5,#T_c8252_row3_col9{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_c8252_row0_col6,#T_c8252_row6_col10,#T_c8252_row9_col0,#T_c8252_row10_col7,#T_c8252_row12_col1,#T_c8252_row12_col10{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_c8252_row0_col7,#T_c8252_row2_col9,#T_c8252_row7_col8,#T_c8252_row9_col2,#T_c8252_row11_col1,#T_c8252_row11_col6{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_c8252_row0_col8,#T_c8252_row2_col1{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T